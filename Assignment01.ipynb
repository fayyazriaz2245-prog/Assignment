# %% [markdown]
# 1.Write a program to check whether a person is eligible for voting or not. (accept age from user) if age is greater than 17 eligible otherwise not eligible

# %%
age=int(input("Enter your age"))
if age >= 17:
    print ("Congratulations You Are Eligible For Voting")
else:
    print("Sorry You Are Not Eligible For Voting")
# Out:
# Congratulations You Are Eligible For Voting

# %% [markdown]
# 2) A company decided to give bonus of 5% to employee if his/her year of service is more than 5 years. Ask user for their salary and year of service and print the net bonus amount

# %%
salary=int(input("Enter Your Salary"))
year_of_service=int(input("Enter Your Year Of Servive"))
if year_of_service > 5:
    bonus = salary * 0.05
    print(f"your bonus is {bonus} Congratulations")
else:
    bonus = 0
    print(f"your Bonus is {bonus}")
# Out:
# your Bonus is 0

# %% [markdown]
# 3) Write a program to check whether a number entered by user is even or odd

# %%
num=int(input("Enter Your Number"))
if num % 2 == 0:
    print("The Number Is Even")
else:
    print("The Number is Odd")
# Out:
# The Number Is Even

# %% [markdown]
# 4) Write a program to check whether a number is divisible by 7 or not. Show Answer

# %%
num=int(input("Enter Your Number"))
if num % 7 == 0:
    print("The Number Is Divided by 7")
else:
    print("The Number Is Not Divided By 7")
# Out:
# The Number Is Divided by 7

# %% [markdown]
# 5) Write a program to display "Hello" if a number entered by user is a multiple of five , otherwise print "Bye"

# %%
num=int(input("Enter Your Number"))
if num % 5 == 0:
    print ("Hello How are You")
else:
    print("Bye")
# Out:
# Hello How are You

# %% [markdown]
# 6) Take values of length and breadth of a rectangle from user and print if it is square or rectangle

# %%
length=int(input("Enter Your Number"))
breath=int(input("Enter Your Number"))
if length == breath:
    print ("This is a square")
else:
    print("This is a Rectangle")
# Out:
# This is a square
